# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# read in our data
earth = pd.read_csv("earthquake.csv")
land = pd.read_csv("landslide_event.csv")
vol = pd.read_csv("volcanic-erruption.csv")

# set seed for reproducibility
np.random.seed(0)

# %%
earth.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
land.head()
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ...  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...
# 1           Ohio       17288  New Philadelphia   3.33522  ...
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...
# 3         Quebec       42786       Châteauguay   2.98682  ...
# 4       Kentucky        6903         Pikeville   5.66542  ...
#
#                                  geolocation  hazard_type      landslide_type  \
# 0  (38.600900000000003, -77.268199999999993)    Landslide           Landslide
# ...

# %%
vol.head()
# Out:
#    Number                       Name  Country                          Region  \
# 0  210010  West Eifel Volcanic Field  Germany  Mediterranean and Western Asia
# 1  210020            Chaine des Puys   France  Mediterranean and Western Asia
# 2  210030        Olot Volcanic Field    Spain  Mediterranean and Western Asia
# 3  210040   Calatrava Volcanic Field    Spain  Mediterranean and Western Asia
# 4  211001                 Larderello    Italy  Mediterranean and Western Asia
#
#                   Type  Activity Evidence Last Known Eruption  Latitude  \
# 0              Maar(s)     Eruption Dated            8300 BCE    50.170
# 1         Lava dome(s)     Eruption Dated            4040 BCE    45.775
# 2  Pyroclastic cone(s)  Evidence Credible             Unknown    42.170
# 3  Pyroclastic cone(s)     Eruption Dated            3600 BCE    38.870
# 4  Explosion crater(s)  Eruption Observed             1282 CE    43.250
#
# ...

# %%
land['date'].dtype
# Out:
# dtype('O')

# %%
earth["Date"].dtype
# Out:
# dtype('O')

# %%
type(2)
# Out:
# int

# %% [markdown]
# 1/17/07 has the format "%m/%d/%y"
# 17-1-2007 has the format "%d-%m-%Y

# %%
land["date-parsed"]=pd.to_datetime(land["date"])
land["date-parsed"]=pd.to_datetime(land["date"],format ="%m/%d/%y")

# %%
land.head()
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ... hazard_type  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...   Landslide
# 1           Ohio       17288  New Philadelphia   3.33522  ...   Landslide
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...   Landslide
# 3         Quebec       42786       Châteauguay   2.98682  ...   Landslide
# 4       Kentucky        6903         Pikeville   5.66542  ...   Landslide
#
#        landslide_type  landslide_size   trigger storm_name injuries  \
# ...

# %%
land['date-parsed'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# What if I run into an error with multiple date formats?
# While we're specifying the date format here, sometimes you'll run into an error when there are multiple date formats in a single column. If that happens, you have have pandas try to infer what the right date format should be. You can do that like so:
# ### land['date_parsed'] = pd.to_datetime(land['Date'], infer_datetime_format=True)
#
# Why don't you always use infer_datetime_format = True?
# There are two big reasons not to always have pandas guess the time format. The first is that pandas won't always been able to figure out the correct date format, especially if someone has gotten creative with data entry. The second is that it's much slower than specifying the exact format of the dates.

# %%
earth["date-parsed"]=pd.to_datetime(earth["Date"])

# %%
earth.sample()
# Out:
#            Date      Time  Latitude  Longitude        Type  Depth  \
# 335  12/26/1965  03:53:12    -5.201    151.583  Earthquake   80.1
#
#      Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 335          NaN                     NaN        5.9             MW  ...
#
#      Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# 335            NaN                  NaN               NaN               NaN
#
#                ID  Source Location Source Magnitude Source     Status  \
# 335  ISCGEM851979  ISCGEM          ISCGEM           ISCGEM  Automatic
#
#              date-parsed
# 335  1965-12-26 00:00:00
#
# [1 rows x 22 columns]

# %%
day_of_month_landslides = land['date-parsed'].dt.day
day_of_month_landslides
# Out:
# 0        2.0
# 1       22.0
# 2        6.0
# 3       14.0
# 4       15.0
# 5       20.0
# 6       24.0
# 7       21.0
# 8       27.0
# 9       27.0
# 10      27.0
# 11       1.0
# 12       4.0
# 13       8.0
# 14      13.0
# 15      24.0
# 16       9.0
# 17      11.0
# 18      14.0
# 19      17.0
# 20      18.0
# 21      18.0
# 22      18.0
# 23      19.0
# 24      19.0
# 25      20.0
# 26      21.0
# 27      21.0
# 28      23.0
# 29       1.0
#         ...
# 1663    17.0
# 1664    10.0
# 1665    31.0
# 1666    31.0
# 1667    22.0
# 1668     9.0
# 1669    23.0
# 1670    21.0
# 1671    21.0
# 1672    12.0
# 1673    15.0
# 1674    24.0
# 1675    24.0
# 1676    15.0
# 1677    24.0
# 1678    21.0
# 1679    24.0
# 1680    28.0
# 1681    24.0
# 1682    27.0
# 1683    27.0
# 1684    14.0
# 1685    26.0
# 1686    27.0
# 1687    29.0
# 1688     7.0
# 1689    22.0
# 1690    23.0
# 1691    26.0
# 1692     2.0
# Name: date-parsed, Length: 1693, dtype: float64

# %%
# remove na's
day_of_month_landslides = day_of_month_landslides.dropna()

# plot the day of the month
sns.distplot(day_of_month_landslides, kde=False, bins=31)
